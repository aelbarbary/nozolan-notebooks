# %% [markdown]
# # 🎯 Section 3: Skill Badges
#
# **POWER:** `nested flex` - HORIZONTAL LAYOUT
#
# Create skill badges displayed in a row using nested flexbox with justify-content: center.
#
# ---
#
# ## 🔵 Problem: Need to Add Skill Badges
#
# **Constraint:** The profile needs skill badges displayed in a row, but they would stack vertically with current layout.

# %%
# %%html
#
# <style>
#   .profile-container {
#     text-align: center;
#     display: flex;
#     flex-direction: column;
#     align-items: center;
#     gap: 15px;
#   }
#   .profile-heading {
#     color: blue;
#   }
#   .profile-text {
#     font-size: 20px;
#   }
#   .profile-image {
#     border: 5px solid purple;
#   }
#   .profile-link {
#     color: darkgreen;
#     text-decoration: none;
#   }
#   .skills-row {
#     display: flex;
#     gap: 10px;
#     justify-content: center;
#   }
#   .skill-badge {
#     background: lightblue;
#     padding: 8px 15px;
#     border-radius: 5px;
#   }
# </style>
#
# <div class="profile-container">
#   <h1 class="profile-heading">Alex Chen</h1>
#   <p class="profile-text">I am a student learning web development.</p>
#   <img class="profile-image" src="https://www.w3schools.com/html/img_chania.jpg" alt="Profile" width="200">
#
#   <div class="skills-row">
#     <div class="skill-badge">HTML</div>
#     <div class="skill-badge">CSS</div>
#     <div class="skill-badge">Python</div>
#   </div>
#
#   <a class="profile-link" href="https://github.com">Visit my GitHub</a>
# </div>

# %% [markdown]
# **Resolution:** A nested flexbox with `flex-direction: row` arranges skill badges horizontally. The `justify-content: center` centers them.
#
# **Task:** Add a fourth skill badge with your favorite skill.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## ➡️ Next Section
#
# **Continue to:** [Section 4 - Project Grid](https://colab.research.google.com/github/aelbarbary/nozolan-notebooks/blob/main/python-level3-ants/lesson3-section4-grid.ipynb)
#
# **Previous:** [Section 2 - Gap Property](https://colab.research.google.com/github/aelbarbary/nozolan-notebooks/blob/main/python-level3-ants/lesson3-section2-gap.ipynb)
#
# **Back to:** [Lesson 3 Index](https://colab.research.google.com/github/aelbarbary/nozolan-notebooks/blob/main/python-level3-ants/lesson3.ipynb)
