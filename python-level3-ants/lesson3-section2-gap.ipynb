# %% [markdown]
# # 📐 Section 2: Items Need Space
#
# **POWER:** `gap` - SPACING CONTROL
#
# Master the gap property to add equal spacing between all flex items.
#
# ---
#
# ## 🔵 Problem: Items Need Space Between Them
#
# **Constraint:** The flex items are arranged but have no spacing between them.

# %%
# %%html
#
# <style>
#   .profile-container {
#     text-align: center;
#     display: flex;
#     flex-direction: column;
#     align-items: center;
#     gap: 15px;
#   }
#   .profile-heading {
#     color: blue;
#   }
#   .profile-text {
#     font-size: 20px;
#   }
#   .profile-image {
#     border: 5px solid purple;
#   }
#   .profile-link {
#     color: darkgreen;
#     text-decoration: none;
#   }
# </style>
#
# <div class="profile-container">
#   <h1 class="profile-heading">Alex Chen</h1>
#   <p class="profile-text">I am a student learning web development.</p>
#   <img class="profile-image" src="https://www.w3schools.com/html/img_chania.jpg" alt="Profile" width="200">
#   <a class="profile-link" href="https://github.com">Visit my GitHub</a>
# </div>
# Out:
# <style>
#   .profile-container {
#     text-align: center;
#     display: flex;
#     flex-direction: column;
#     align-items: center;
#     gap: 15px;
#   }
#   .profile-heading {
#     color: blue;
#   }
#   .profile-text {
#     font-size: 20px;
#   }
#   .profile-image {
#     border: 5px solid purple;
#   }
#   .profile-link {
#     color: darkgreen;
#     text-decoration: none;
#   }
# </style>
#
# <div class="profile-container">
#   <h1 class="profile-heading">Alex Chen</h1>
#   <p class="profile-text">I am a student learning web development.</p>
#   <img class="profile-image" src="https://www.w3schools.com/html/img_chania.jpg" alt="Profile" width="200">
#   <a class="profile-link" href="https://github.com">Visit my GitHub</a>
# </div>

# %% [markdown]
# **Resolution:** The `gap` property adds equal spacing between all flex items, replacing individual margin-bottom values.
#
# **Task:** Change `15px` to `30px` or `5px`.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## ➡️ Next Section
#
# **Continue to:** [Section 3 - Skill Badges](https://colab.research.google.com/github/aelbarbary/nozolan-notebooks/blob/main/python-level3-ants/lesson3-section3-badges.ipynb)
#
# **Previous:** [Section 1 - Flexbox Basics](https://colab.research.google.com/github/aelbarbary/nozolan-notebooks/blob/main/python-level3-ants/lesson3-section1-flexbox.ipynb)
#
# **Back to:** [Lesson 3 Index](https://colab.research.google.com/github/aelbarbary/nozolan-notebooks/blob/main/python-level3-ants/lesson3.ipynb)
