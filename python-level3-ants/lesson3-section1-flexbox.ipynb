# %% [markdown]
# ## 🚀 Mission
#
# Your mission is to control how elements are arranged on your profile page using CSS layout.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 🔧 Tool Introduction
#
# We will use CSS Flexbox as a layout system. This tool controls how elements are positioned and arranged on the page.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 🔵 Problem: Need Better Layout Control
#
# **Constraint:** The profile elements use individual margins for spacing, making it hard to control the layout consistently.
#
# https://colab.research.google.com/github/aelbarbary/nozolan-notebooks/blob/main/python-level3-ants/lesson2.ipynb

# %%
# %%html
#
# <style>
#   .profile-container {
#     text-align: center;
#     display: flex;
#     flex-direction: column;
#     align-items: center;
#   }
#   .profile-heading {
#     color: green;
#     margin-bottom: 20px;
#
#   }
#   .profile-text {
#     font-size: 20px;
#     margin-bottom: 20px;
#   }
#   .profile-image {
#     border: 5px solid purple;
#     margin-bottom: 20px;
#   }
#   .profile-link {
#     color: darkgreen;
#     text-decoration: none;
#   }
# </style>
#
# <div class="profile-container">
#   <h1 class="profile-heading">Alex Chen</h1>
#   <p class="profile-text">I am a student learning web development.</p>
#   <img class="profile-image" src="https://www.w3schools.com/html/img_chania.jpg" alt="Profile" width="200">
#   <a class="profile-link" href="https://github.com">Visit my GitHub</a>
# </div>

# %% [markdown]
# **Resolution:** The `display: flex` property turns the container into a flexbox. The `align-items: center` centers all items horizontally.
#
# **Task:** Remove `align-items: center` and see what happens to the image.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## ➡️ Next Section
#
# **Continue to:** [Section 2 - Items Need Space](https://colab.research.google.com/github/aelbarbary/nozolan-notebooks/blob/main/python-level3-ants/lesson3-section2-gap.ipynb)
#
# **Back to:** [Lesson 3 Index](https://colab.research.google.com/github/aelbarbary/nozolan-notebooks/blob/main/python-level3-ants/lesson3.ipynb)
