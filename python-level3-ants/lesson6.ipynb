# %% [markdown]
# # 🌟 Flask Profile + Savings (PythonAnywhere)
#
# Today you will run a starter website that has:
# - A profile page
# - A **Savings** number you can increase
# - A **Zakat** button (2.5%)
#
# You will upload it to **PythonAnywhere** and make ONE small update.

# %% [markdown]
# ---
# ---
#
# ## 🔵 SECTION 1: RUN THE STARTER WEBSITE (SAVINGS + ZAKAT)
#
# ### Step 1: Download the starter code (mysite.zip)
#
# Download `mysite.zip` and save it on your computer.
#
# Link:
# https://github.com/aelbarbary/nozolan-notebooks/blob/main/python-level3-ants/code/class6/mysite.zip
#
# Tip: On GitHub, click **Download raw file** (or click the **⋯** menu and download).
#
# ### Step 2: Example (Upload + Run on PythonAnywhere)
#
# 1. PythonAnywhere → **Files**
# 2. Open your folder: `mysite/` (it’s usually already there)
# 3. Upload: `mysite.zip`
# 4. PythonAnywhere → **Consoles** → Start a **Bash** console
# 5. Run:
#
# ```bash
# cd ~/mysite
# unzip -o mysite.zip
# ```
#
# 6. PythonAnywhere → **Web** → click **Reload**
# 7. Open your website link (it looks like `https://YOURUSERNAME.pythonanywhere.com/`)
#
# ### Step 3: Challenge
#
# <strong style="color:#f59e0b;">🔥💻 CHALLENGE: Add a Saving Goal 💻🔥</strong>
#
# 1. On PythonAnywhere → **Files** → open `mysite/profile.json`
# 2. Add a new field called `saving_goal`
#
# Example:
# - `"saving_goal": 300`
#
# 3. Now open your profile page file and show it on the page:
#    - Open `mysite/templates/index.html`
#    - Add a new line that displays the saving goal (near the Savings section)
#
# 4. Save your files, then **Reload** and refresh your website.
#
# If nothing changes:
# - Click **Reload** again
# - Check **Web → Log files**

# %% [markdown]
# ---
# ---
#
# ## 🎤 SHOW & TELL (VERY IMPORTANT)
#
# Show your website to a parent or friend.
#
# Answer these:
# - What did you build today?
# - What does the **Add** button do?
# - What does the **Zakat** button do?
# - What new field did you add (Saving Goal)?

# %% [markdown]
# ---
# ---

# %% [markdown]
# ---
# ---
#
# ## 🧠 QUICK QUIZ
#
# 1. What file stores your profile info on this project?
# 2. True or False: `templates/` is where HTML files go in Flask.
# 3. True or False: `static/` is where CSS files go in Flask.
# 4. What does the `/add-saving` endpoint do?
# 5. What new field did you add for this lesson?
